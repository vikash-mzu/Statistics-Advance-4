# %%
Q1: Difference between a t-test and a z-test?
•	T-test: Used when the population standard deviation is unknown and the sample size is small (n < 30). It is based on the t-distribution.
o	Example: Comparing the average height of 20 people to the national average when the population standard deviation is unknown.
•	Z-test: Used when the population standard deviation is known and the sample size is large (n ≥ 30). It is based on the z-distribution (normal distribution).
o	Example: Comparing the average salary of 1000 employees to the national average, with the population standard deviation known.
________________________________________
Q2: One-tailed vs Two-tailed Tests
•	One-tailed test: Used when the hypothesis specifies the direction of the effect (e.g., greater than or less than).
o	Example: Testing if a new teaching method increases student scores (greater than the current method).
•	Two-tailed test: Used when the hypothesis does not specify the direction (e.g., whether there is any difference).
o	Example: Testing if a new drug has a different effect than the current one (could be better or worse).
________________________________________
Q3: Type 1 and Type 2 Errors
•	Type 1 Error (False Positive): Rejecting the null hypothesis when it is true.
o	Example: Concluding a drug is effective when it actually isn't.
•	Type 2 Error (False Negative): Failing to reject the null hypothesis when it is false.
o	Example: Concluding a drug is not effective when it actually is.
________________________________________
Q4: Bayes' Theorem Explanation
Bayes' Theorem calculates the probability of an event based on prior knowledge of related events.
Formula:
P(A∣B)=P(B∣A)⋅P(A)P(B)P(A|B) = \frac{P(B|A) \cdot P(A)}{P(B)}P(A∣B)=P(B)P(B∣A)⋅P(A)
Example: A factory produces 95% of products with good quality and 5% with defects. A test detects 90% of defects. If a product fails the test, what is the probability it is defective?
Given:
•	P(defective)=0.05P(\text{defective}) = 0.05P(defective)=0.05
•	P(good)=0.95P(\text{good}) = 0.95P(good)=0.95
•	P(fail | defective)=0.9P(\text{fail | defective}) = 0.9P(fail | defective)=0.9
•	P(fail | good)=0.1P(\text{fail | good}) = 0.1P(fail | good)=0.1
Using Bayes’ Theorem, you can calculate P(defective | fail)P(\text{defective | fail})P(defective | fail).
________________________________________
Q5: Confidence Interval Explanation
A confidence interval (CI) provides a range within which the population parameter is expected to lie, with a certain level of confidence (e.g., 95%).
Formula:
CI=xˉ±Z(σn)CI = \bar{x} \pm Z \left( \frac{\sigma}{\sqrt{n}} \right)CI=xˉ±Z(nσ)
Example: If the mean height of 100 people is 170 cm with a standard deviation of 10 cm, the 95% confidence interval would be:
CI=170±1.96(10100)=170±1.96×1=[168.04,171.96]CI = 170 \pm 1.96 \left( \frac{10}{\sqrt{100}} \right) = 170 \pm 1.96 \times 1 = [168.04, 171.96]CI=170±1.96(10010)=170±1.96×1=[168.04,171.96]
________________________________________
Q6: Bayes' Theorem Application
Problem: A disease affects 1% of the population. A test is 99% accurate for detecting the disease. If a person tests positive, what is the probability they have the disease?
Given:
•	P(disease)=0.01P(\text{disease}) = 0.01P(disease)=0.01
•	P(no disease)=0.99P(\text{no disease}) = 0.99P(no disease)=0.99
•	P(positive | disease)=0.99P(\text{positive | disease}) = 0.99P(positive | disease)=0.99
•	P(positive | no disease)=0.01P(\text{positive | no disease}) = 0.01P(positive | no disease)=0.01
Use Bayes’ Theorem to find P(disease | positive)P(\text{disease | positive})P(disease | positive).
________________________________________
Q7: 95% Confidence Interval for Mean = 50, SD = 5
Given:
•	Mean (xˉ\bar{x}xˉ) = 50
•	Standard deviation (σ\sigmaσ) = 5
•	95% confidence level (Z = 1.96)
CI=50±1.96(5n)CI = 50 \pm 1.96 \left( \frac{5}{\sqrt{n}} \right)CI=50±1.96(n5)
For a sample size of nnn, you would calculate the margin of error and construct the interval.
________________________________________
Q8: Margin of Error and Sample Size
The margin of error (MOE) measures the uncertainty in an estimate.
MOE=Z(σn)MOE = Z \left( \frac{\sigma}{\sqrt{n}} \right)MOE=Z(nσ)
A larger sample size decreases the margin of error because n\sqrt{n}n increases.
Example: A survey with 100 participants has a margin of error of ±5%. If the sample size increases to 400, the margin of error would decrease to ±2.5%.
________________________________________
Q9: Z-score Calculation
Given:
•	Value = 75
•	Population mean = 70
•	Population standard deviation = 5
Z=75−705=1Z = \frac{75 - 70}{5} = 1Z=575−70=1
Interpretation: The data point is 1 standard deviation above the mean.
________________________________________
Q10: Hypothesis Test for Weight Loss Drug
Given:
•	Mean weight loss = 6 pounds
•	SD = 2.5 pounds
•	Sample size = 50
Use the t-test formula to calculate the t-statistic and compare it to the critical value for a 95% confidence level to determine significance.
________________________________________
Q11: Confidence Interval for Proportion
Given:
•	Proportion = 65%
•	Sample size = 500
•	95% confidence level
Use the formula for a proportion’s confidence interval:
CI=p±Zp(1−p)nCI = p \pm Z \sqrt{\frac{p(1-p)}{n}}CI=p±Znp(1−p)
________________________________________
Q12: Hypothesis Test for Teaching Methods
Given:
•	Sample A: Mean = 85, SD = 6
•	Sample B: Mean = 82, SD = 5
•	Significance level = 0.01
Perform a t-test for two independent samples to determine if there is a significant difference in the means.
________________________________________
Q13: 90% Confidence Interval for Population Mean
Given:
•	Population mean = 60, SD = 8
•	Sample mean = 65
•	Sample size = 50
Calculate the 90% confidence interval using the standard formula.
________________________________________
Q14: Hypothesis Test for Caffeine’s Effect on Reaction Time
Given:
•	Mean reaction time = 0.25 seconds
•	SD = 0.05 seconds
•	Sample size = 30
Conduct a t-test to determine if the caffeine has a significant effect at a 90% confidence level.
